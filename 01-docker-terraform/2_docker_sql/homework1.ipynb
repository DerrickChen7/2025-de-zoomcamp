# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv('green_tripdata_2019-10.csv.gz')
# Out:
# /var/folders/r4/dq625q7d2rz5s83thp2p24hc0000gn/T/ipykernel_96227/2667354967.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('green_tripdata_2019-10.csv.gz')

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
df.head(0).to_sql('green_taxi_trips', con=engine, if_exists='replace', index=False)
# Out:
# 0

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv.gz', iterator=True, chunksize=100000)

# %%
while True:
    t_start = time()

    df = next(df_iter)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df.to_sql('green_taxi_trips', con=engine, if_exists='append', index=False)

    t_end = time()
    print('inserted 100k rows in', t_end - t_start, 'seconds')
# Out:
# inserted 100k rows in 6.295708894729614 seconds
# inserted 100k rows in 6.240667104721069 seconds
# inserted 100k rows in 6.321465015411377 seconds
# /var/folders/r4/dq625q7d2rz5s83thp2p24hc0000gn/T/ipykernel_96227/1980540873.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted 100k rows in 6.551275730133057 seconds
# inserted 100k rows in 4.337555885314941 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#       7     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# ...

# %%
df = pd.read_csv('taxi_zone_lookup.csv')
df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df.head(0).to_sql('taxi_zone_lookup', con=engine, if_exists='replace', index=False)
df_iter = pd.read_csv('taxi_zone_lookup.csv', iterator=True, chunksize=100000)
while True:
    t_start = time()

    df = next(df_iter)

    df.to_sql('taxi_zone_lookup', con=engine, if_exists='append', index=False)

    t_end = time()
    print('inserted 100k rows in', t_end - t_start, 'seconds')
# Out:
# inserted 100k rows in 0.012193918228149414 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 6
#       3 while True:
#       4     t_start = time()
# ----> 6     df = next(df_iter)
#       8     df.to_sql('taxi_zone_lookup', con=engine, if_exists='append', index=False)
#      10     t_end = time()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# ...
